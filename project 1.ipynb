# %% [markdown]
# ## 1A: English Dictionary App

# %%
print( '''WELCOME TO MY DICTIONARY APPLICATION!''')
print('1.Add a new word')
print('2.Find the Meaning')
print('3.Update the word')
print('4.Exit')
# Out:
# WELCOME TO MY DICTIONARY APPLICATION!
# 1.Add a new word
# 2.Find the Meaning
# 3.Update the word
# 4.Exit

# %%
import pickle
import os

# %%
def saveDictionary(my_dict):
    '''
    This function recives a python dictionary,
    and saves it to a serialized file words.txt
    '''
    try:
        with open('words.txt', 'wb') as dictionary:
            pickle.dump(my_dict, dictionary)
        '''dictionary = open('words.txt', 'wb')
        # pickle.dump(my_dict, dictionary)
        # dictionary.close()'''
        print("SUCCESS: writing to dictionary words.txt")
    except Exception as e:
        print(f"ERROR: {e}")


def getDictionary():
    '''
    This function returns a python dictionary,
    after de-serializing the file words.txt
    '''
    try:
       
        with open('words.txt', 'rb') as dictionary:
            my_dict = pickle.load(dictionary)
        print("SUCCESS: reading from dictionary words.txt")
        return my_dict
    except Exception as e:
        print(f"ERROR: {e}")


#2. User-Software Interface

def add_New_Word():
    '''
    This function provides functionalities for n==1,
    that is, it creates a new word in the dictionary
    '''
    print("__________")
    print("NEW WORD ADDER:")
    print("__________")
    print("Enter a Word to add")
    word = input(">>")
    print(f"Enter a meaning of {word} to add")
    meaning = input(">>")
    dictionary = getDictionary()
    dictionary[word] = meaning
    saveDictionary(dictionary)

   
    main_menu()


def find_Meaning():
    '''
    This function provides functionalities for n==2,
    that is, it finds a word in the dictionary
    '''
    print("__________")
    print("WORD FINDER:")
    print("__________")
    print("Enter a Word to find")
    word = input(">>")
    dictionary = getDictionary()
 
    if word in dictionary:
        print(f"Found_Entry: [{word} : {dictionary[word]}]")
    else:
   
        print("ERROR: The word doesn't exist!")
        findMeaning()

   
    main_menu()


def update_Word():
    '''
    This function provides functionalities for n==3,
    that is, it updates a word in the dictionary
    '''
    print("__________")
    print("WORD UPDATER:")
    print("__________")
    print("Enter an old Word to edit")
    word = input(">>")
   
    dictionary = getDictionary()
    if word in dictionary:
        print(f"Enter a New Meaning to edit [{word} : {dictionary[word]}] to:")
        new_meaning = input(">>")
        dictionary[word] = new_meaning
        saveDictionary(dictionary)
        print(f"SUCCESS: Updated to [{word} : {dictionary[word]}]")
    else:
 
        print("ERROR: The word doesn't exist! impossible to update!")
        updateWord()

   
    main_menu()


def main_menu():
    '''
    This function prints Main Menu:
    __________
    ENGLISH DICTIONARY APP
    __________
    1. Add a new word
    2. Find the meaning
    3. Update a word
    4. Exit
    __________
    '''
    if not os.path.exists(os.path.join("words.txt")):
        try:
            with open('words.txt', 'wb') as dictionary:
                pickle.dump({}, dictionary)
            print("SUCCESS: writing to dictionary words.txt")
        except Exception as e:
            print(f"ERROR: {e}")
    print("__________")
    print("ENGLISH DICTIONARY APP")
    print("__________")
    print("1. Add a new word")
    print("2. Find the meaning")
    print("3. Update a word")
    print("4. Exit")
    print("__________")
    
    n = int(input(">>"))
    if n==1:
     
        add_New_Word()
    elif n==2:
       
        find_Meaning()
    elif n==3:
        update_Word()
    elif n==4:
        exit()
    else:
       
        print("ERROR: Please Enter a digit according to Menu.")
main_menu()
# Out:
# __________
# ENGLISH DICTIONARY APP
# __________
# 1. Add a new word
# 2. Find the meaning
# 3. Update a word
# 4. Exit
# __________
# >>4

# %% [markdown]
# ## 1B: Library Book Management System

# %%
print(''' GUI developed using Tkinter and the backend database implemented in SQLite.
      It is a single window tkinter GUI application which will implement CRUD( create, read, update, delete) operations on a 
      ‘books’ database, in SQLite. 
      The window will contain text widgets to accept / display book title, author, year of publication, ISBN (optional)''')
# Out:
#  GUI developed using Tkinter and the backend database implemented in SQLite.
#       It is a single window tkinter GUI application which will implement CRUD( create, read, update, delete) operations on a
#       ‘books’ database, in SQLite.
#       The window will contain text widgets to accept / display book title, author, year of publication, ISBN (optional)

# %%
from tkinter import *
import sqlite3
import tkinter.ttk as ttk
import tkinter.messagebox as tkmessagebox

# %%
root=Tk()
root.title('Library Book Management System')
# Out:
# ''

# %%
# Database connect
def Database():
    global conn,cursor
    conn =sqlite3.connect('simple.db')
    cursor=conn.cursor()
    cursor.execute("CREATE TABLE IF NOT EXISTS library(book_id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,Booktitle TEXT, Author TEXT ,Year INTEGER ,ISBN TEXT )")


# create function 


def create():
    if BOOKTITLE.get()=="" or AUTHOR.get()== "" or YEAR.get()== "" or ISBN.get() == "":
        txt_result.config(text="Please enter all the field",fg="red")
    else :
        Database()
        cursor.execute("INSERT INTO library(Booktitle,Author,Year,ISBN) VALUES(?,?,?,?,) ",(str(Booktitle.get()),str(Author.get()),int(Year.get()),str(ISBN.get()),))
        conn.commit()
        ISBN.set("")
        BOOKTITLE.set("")
        AUTHOR.set("")
        YEAR.set("")
        cursor.close()
        conn.close()
        txt_result.config(text="Record Inserted  !",fg="green")

# read function

def Read():
    tree.delete(*tree.get_children())
    Database()
    cursor.execute("SELECT* FROM library ORDER BY Author ASC")
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
    cursor.close()
    txt_result.config(text= "Successefully",fg="black")
    
    
    
# Display function

def display():
    tree.delete(*tree.get_children())
    Database()
    cursor.execute("SELECT* FROM library ORDER BY Author ASC")
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
    cursor.close()
    txt_result.config(text= "Successefully",fg="black")
    
    
# Search functin    
    
def search():
    if BOOKTITLE.get()=="" or AUTHOR.get()== "" or YEAR.get()== "" or ISBN.get()== "":
        txt_result.config(text="Please enter all the field",fg="red")
    else:
         tree.delete(*tree.get_children())
    Database()
    cursor.execute("SELECT * FROM library(Booktitle,Author,Year,ISBN) VALUES (?,?,?,?)",(str(Booktitle.get()),str(Author.get()),int(Year.get()),str(ISBN.get()),))
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
    cursor.close()
    txt_result.config(text= "Successefully",fg="black")
    
# Delete Function

def delete():
    if BOOKTITLE.get()=="" or AUTHOR.get()== "" or YEAR.get()== "" or ISBN.get()== "":
        txt_result.config(text="Please enter all the field",fg="red")
    else:
        
        tree.delete(*tree.get_children())
    Database()
    cursor.execute("DELETE * FROM library(Booktitle,Author,Year,ISBN) VALUES(?,?,?,?)",(str(Booktitle.get()),str(Author.get()),int(Year.get()),str(ISBN.get()),))
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end',values=(data[1],data[2],data[3],data[4]))
    cursor.close()
    txt_result.config(text= "Successefully",fg="black")
    

    
    
# Exit function    
    
def Exit():
    result=tkmessagebox.askquestion('Do you want to Exit ?(y/n)',icon='warning')
    if result== 'yes':
        root.destroy()
        exit()

# %%
# ==============================================================variable decalration============================================


BOOKTITLE=StringVar()
AUTHOR=StringVar()
YEAR=StringVar()
ISBN = StringVar()

# %%
#======================================================== Frame================================================================

Top=Frame(root, width=900, height=50, bd=8, relief='raise',bg="blue")
Top.pack(side=TOP)
Left=Frame(root, width=450, height=500, bd=8, relief='raise' ,bg="red")
Left.pack(side=LEFT)
Right=Frame(root, width= 450,height=400,bd=8,relief='raise' ,bg="yellow")
Right.pack(side=LEFT)

Forms=Frame(Left,width=300,height=450)
Forms.pack(side=TOP)

Buttons=Frame(Left,width=300,height=100,bd=8,relief='raise')
Buttons.pack(side=BOTTOM)

# ========================================================LEBEL WIDGET===============================================================
txt_title=Label(Top, width=900,font=('arial',26),text= "... Library Management Application...",bd=20,relief=RIDGE  )
txt_title.pack()
txt_Booktitle=Label(Forms,text="Booktitle:",font=('arial',16),bd=15)
txt_Booktitle.grid(row=0,stick='e')
txt_Author=Label(Forms,text="Author:",font=('arial',16),bd=15)
txt_Author.grid(row=1,stick='e')
txt_Year=Label(Forms,text="Year:",font=('arial',16),bd=15)
txt_Year.grid(row=2,stick='e')
txt_ISBN=Label(Forms,text="ISBN:",font=('arial',16),bd=15)
txt_ISBN.grid(row=3,stick='e')
txt_result=Label(Buttons)
txt_result.pack(side=TOP)


# ======================================================ENTRY WIDGET===========================================================
Booktitle=Entry(Forms,textvariable=BOOKTITLE,width=50)
Booktitle.grid(row=0,column=1)
Author=Entry(Forms,textvariable=AUTHOR,width=50)
Author.grid(row=1,column=1)
Year=Entry(Forms,textvariable=YEAR, width=50)
Year.grid(row=2,column=1)
ISBN=Entry (Forms,textvariable = ISBN,width=50)
ISBN.grid(row=3,column=1)


# =======================================================BOTTON WIDGET==========================================================
btn_create=Button(Buttons,width=10,text="Display",command= display)
btn_create.pack(side=LEFT)
btn_search=Button(Buttons,width=10,text="Search",command=search)
btn_search.pack(side=LEFT)
btn_add=Button(Buttons,width=10,text="Add",command=create)
btn_add.pack(side=LEFT)
btn_issue=Button(Buttons,width=10,text="Issue",command=Read)
btn_issue.pack(side=LEFT)
btn_delete=Button(Buttons,width=10,text="Delete",command=delete)
btn_delete.pack(side=LEFT)
btn_exit=Button(Buttons,width=10,text="Exit",command=Exit)
btn_exit.pack(side=LEFT)


# ========================================================LIST WIDGET ============================================================


scrollbary=Scrollbar(Right,orient=VERTICAL)
scrollbarx=Scrollbar(Right,orient= HORIZONTAL)

tree=ttk.Treeview(Right,columns=("Booktitle","Author","Year","ISBN"))

scrollbary.config(command=tree.yview)
scrollbary.pack(side=RIGHT,fill=Y)
scrollbarx.config(command=tree.xview)
scrollbarx.pack(side=BOTTOM,fill=X)
tree.heading('Booktitle',text="Booktitle:",anchor=W)
tree.heading('Author',text="Author:",anchor=W)
tree.heading('Year',text="Year:",anchor=W)
tree.heading('ISBN',text="ISBN:",anchor=W)
tree.column('#0',stretch=NO,minwidth=0,width=0)
tree.column('#1',stretch=NO,minwidth=0,width=80)
tree.column('#2',stretch=NO,minwidth=0,width=80)
tree.column('#3',stretch=NO,minwidth=0,width=90)
tree.pack()


# =============================================================INITIALIZATION====================================================
if __name__ == '__main__':
    root.mainloop()

# %%
# this is my first project i have no idea how to do complete project but 
#I am try my best for this project completed
# if any errors plz guide me at starting Point for this project
